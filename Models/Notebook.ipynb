# %%
# !pip install pandas     # or conda install pandas, whatever your env uses
# Out:
# Running cells with '.venv (Python 3.12.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"d:/ML code works/Telecom Churn Predictor/.venv/bin/python.exe" -m pip install ipykernel -U --force-reinstall'
